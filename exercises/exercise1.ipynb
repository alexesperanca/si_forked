# %%
import os

print(os.getcwd())
os.chdir("../")
print(os.getcwd())
# Out:
# c:\Users\alexa\Desktop\FACULDADE\Mestrado\2ano\si_forked\exercises
# c:\Users\alexa\Desktop\FACULDADE\Mestrado\2ano\si_forked

# %%
import src.si.data.io.csv as csv_modules
import src.si.data.io.data_file as data_file_modules
from src.si.data.dataset import Dataset
import pandas as pd

IRIS_PATH = "datasets/iris.csv"

# %% [markdown]
#  1.1) Neste exercício, vamos usar o iris dataset. Carrega o iris.csv usando o método read apropriado para o tipo de ficheiro.

# %%
iris_data = csv_modules.read_csv(IRIS_PATH, sep=",")
print(iris_data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
#  1.2) Seleciona a primeira variável independente e verifica a dimensão do array resultante.

# %%
ind_var = iris_data["sepal_length"]
iris_obj = Dataset(ind_var)
iris_obj.shape()
# Out:
# 150

# %% [markdown]
#  1.3) Seleciona as últimas 5 amostras do iris dataset. Qual a média das últimas 5 amostras para cada variável independente/feature?

# %%
final_rows = iris_data.tail(5)
for column in final_rows:
    if not final_rows.dtypes[column] == "float64":
        continue
    col_obj = Dataset(final_rows[column])
    print(col_obj.get_mean())
# Out:
# 6.32
# 2.98
# 5.18
# 2.06

# %% [markdown]
#  1.4) Seleciona todas as amostras do dataset com valor superior ou igual a 1. Nota que o array resultante deve ter apenas amostras com valores iguais ou superiores a 1 para todas as features.

# %%
superior_values = iris_data.loc[(iris_data['sepal_length'] >= 1) & (iris_data['sepal_width'] >= 1) & (iris_data['petal_length'] >= 1) & (iris_data['petal_width'] >= 1)]
superior_values
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [100 rows x 5 columns]

# %% [markdown]
# 1.5) Seleciona todas as amostras com a classe/label igual a ‘Iris-setosa’. Quantas amostras obténs?

# %%
iris_setosa = iris_data.loc[iris_data['class'] == "Iris-setosa"]
iris_setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 17           5.1          3.5           1.4          0.3  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
# 19           5.1          3.8           1.5          0.3  Iris-setosa
# 20           5.4          3.4           1.7          0.2  Iris-setosa
# 21           5.1          3.7           1.5          0.4  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa
# 24           4.8          3.4           1.9          0.2  Iris-setosa
# 25           5.0          3.0           1.6          0.2  Iris-setosa
# 26           5.0          3.4           1.6          0.4  Iris-setosa
# 27           5.2          3.5           1.5          0.2  Iris-setosa
# 28           5.2          3.4           1.4          0.2  Iris-setosa
# 29           4.7          3.2           1.6          0.2  Iris-setosa
# 30           4.8          3.1           1.6          0.2  Iris-setosa
# 31           5.4          3.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa
# 34           4.9          3.1           1.5          0.1  Iris-setosa
# 35           5.0          3.2           1.2          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa
# 37           4.9          3.1           1.5          0.1  Iris-setosa
# 38           4.4          3.0           1.3          0.2  Iris-setosa
# 39           5.1          3.4           1.5          0.2  Iris-setosa
# 40           5.0          3.5           1.3          0.3  Iris-setosa
# 41           4.5          2.3           1.3          0.3  Iris-setosa
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 43           5.0          3.5           1.6          0.6  Iris-setosa
# 44           5.1          3.8           1.9          0.4  Iris-setosa
# 45           4.8          3.0           1.4          0.3  Iris-setosa
# 46           5.1          3.8           1.6          0.2  Iris-setosa
# 47           4.6          3.2           1.4          0.2  Iris-setosa
# 48           5.3          3.7           1.5          0.2  Iris-setosa
# 49           5.0          3.3           1.4          0.2  Iris-setosa
